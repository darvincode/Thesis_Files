# %%
import rdkit
from rdkit import Chem
import os
import random
import pandas as pd
import time
import numpy as np
#import mdtraj as md
import nglview
import openmm
from openbabel import openbabel

from openff.toolkit.topology import Molecule, Topology
from openff.toolkit.typing.engines.smirnoff import ForceField
from openff.toolkit.utils import get_data_file_path
from openff.toolkit.utils.toolkits import RDKitToolkitWrapper, OpenEyeToolkitWrapper, AmberToolsToolkitWrapper
from openff.units import unit
from pandas import read_csv

from openff.interchange import Interchange
from openff.interchange.components._packmol import UNIT_CUBE, pack_box, RHOMBIC_DODECAHEDRON
from openff.interchange.components._packmol import _max_dist_between_points, _compute_brick_from_box_vectors, _center_topology_at
from openmm.openmm import System
from openmm import MonteCarloBarostat

import subprocess
from openmm.app.simulation import Simulation
#from  rdkit  import  Chem
from  rdkit.Chem  import  rdDistGeom
from  rdkit.Chem.Draw  import  IPythonConsole
import warnings
warnings.filterwarnings('ignore')

# %%
smi = 'COC1=C(C2=CC3=C(C=C(OC)C(OC)=C3)N2)SC(C4=CC=CC5=NSN=C54)=C1'

dimer_openff = Molecule.from_file('darvin_mol_1_set_ang.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 9
#       6 #Convert to OpenFF topology
#       7 openff_top = dimer_openff.to_topology()
# ----> 9 interchange = Interchange.from_smirnoff(topology=openff_top,
#      10                                         force_field=ForceField("openff-2.2.0.offxml"))
#      12 interchange.to_pdb("interchange.pdb")
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/components/interchange.py:150, in Interchange.from_smirnoff(cls, force_field, topology, box, positions, charge_from_molecules, partial_bond_orders_from_molecules, allow_nonintegral_charges)
#      95 """
#      96 Create a new object by parameterizing a topology with a SMIRNOFF force field.
#      97
#    (...)
#     146
#     147 """
#     148 from openff.interchange.smirnoff._create import _create_interchange
# --> 150 return _create_interchange(
#     151     force_field=force_field,
#     152     topology=topology,
#     153     box=box,
#     154     positions=positions,
#     155     charge_from_molecules=charge_from_molecules,
#     156     partial_bond_orders_from_molecules=partial_bond_orders_from_molecules,
#     157     allow_nonintegral_charges=allow_nonintegral_charges,
#     158 )
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_create.py:137, in _create_interchange(force_field, topology, box, positions, charge_from_molecules, partial_bond_orders_from_molecules, allow_nonintegral_charges)
#     134 _impropers(interchange, force_field, interchange.topology)
#     136 _vdw(interchange, force_field, interchange.topology)
# --> 137 _electrostatics(
#     138     interchange,
#     139     force_field,
#     140     interchange.topology,
#     141     charge_from_molecules,
#     142     allow_nonintegral_charges,
#     143 )
#     144 _plugins(interchange, force_field, interchange.topology)
#     146 _virtual_sites(interchange, force_field, interchange.topology)
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_create.py:292, in _electrostatics(interchange, force_field, topology, charge_from_molecules, allow_nonintegral_charges)
#     287     else:
#     288         return
#     290 interchange.collections.update(
#     291     {
# --> 292         "Electrostatics": SMIRNOFFElectrostaticsCollection.create(
#     293             parameter_handler=[
#     294                 handler
#     295                 for handler in [
#     296                     force_field._parameter_handlers.get(name, None)
#     297                     for name in [
#     298                         "Electrostatics",
#     299                         "ChargeIncrementModel",
#     300                         "ToolkitAM1BCC",
#     301                         "LibraryCharges",
#     302                     ]
#     303                 ]
#     304                 if handler is not None
#     305             ],
#     306             topology=topology,
#     307             charge_from_molecules=charge_from_molecules,
#     308             allow_nonintegral_charges=allow_nonintegral_charges,
#     309         ),
#     310     },
#     311 )
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_nonbonded.py:455, in SMIRNOFFElectrostaticsCollection.create(cls, parameter_handler, topology, charge_from_molecules, allow_nonintegral_charges)
#     441 toolkit_handler_with_metadata = [p for p in parameter_handlers if type(p) is ElectrostaticsHandler][0]
#     443 handler = cls(
#     444     type=toolkit_handler_with_metadata.TAGNAME,
#     445     scale_12=toolkit_handler_with_metadata.scale12,
#    (...)
#     452     exception_potential=toolkit_handler_with_metadata.exception_potential,
#     453 )
# --> 455 handler.store_matches(
#     456     parameter_handlers,
#     457     topology,
#     458     charge_from_molecules=charge_from_molecules,
#     459     allow_nonintegral_charges=allow_nonintegral_charges,
#     460 )
#     461 handler._charges = dict()
#     463 return handler
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_nonbonded.py:856, in SMIRNOFFElectrostaticsCollection.store_matches(self, parameter_handler, topology, charge_from_molecules, allow_nonintegral_charges)
#     851 # TODO: Here is where the toolkit calls self.check_charges_assigned(). Do we skip this
#     852 #       entirely given that we are not accepting `charge_from_molecules`?
#     854 if not flag:
#     855     # TODO: Rename this method to something like `_find_matches`
# --> 856     matches, potentials = self._find_reference_matches(
#     857         parameter_handlers,
#     858         unique_molecule,
#     859     )
#     861 self.potentials.update(potentials)
#     863 for unique_molecule_atom in unique_molecule.atoms:
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_nonbonded.py:720, in SMIRNOFFElectrostaticsCollection._find_reference_matches(cls, parameter_handlers, unique_molecule)
#     710     slot_matches, slot_potentials = cls._find_slot_matches(
#     711         parameter_handler,
#     712         unique_molecule,
#     713     )
#     715 if handler_type in ["ToolkitAM1BCC", "ChargeIncrementModel"]:
#     716     (
#     717         partial_charge_method,
#     718         am1_matches,
#     719         am1_potentials,
# --> 720     ) = cls._find_charge_model_matches(
#     721         parameter_handler,
#     722         unique_molecule,
#     723     )
#     725 if slot_matches is None and am1_matches is None:
#     726     raise NotImplementedError()
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_nonbonded.py:658, in SMIRNOFFElectrostaticsCollection._find_charge_model_matches(cls, parameter_handler, unique_molecule)
#     652 else:
#     653     raise InvalidParameterHandlerError(
#     654         f"Encountered unknown handler of type {type(parameter_handler)} where only "
#     655         "ToolkitAM1BCCHandler or ChargeIncrementModelHandler are expected.",
#     656     )
# --> 658 partial_charges = cls._compute_partial_charges(
#     659     unique_molecule,
#     660     unique_molecule.to_smiles(
#     661         isomeric=True,
#     662         explicit_hydrogens=True,
#     663         mapped=True,
#     664     ),
#     665     method=partial_charge_method,
#     666 )
#     668 matches = {}
#     669 potentials = {}
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_nonbonded.py:475, in SMIRNOFFElectrostaticsCollection._compute_partial_charges(cls, molecule, mapped_smiles, method)
#     473 """Call out to the toolkit's toolkit wrappers to generate partial charges."""
#     474 molecule = copy.deepcopy(molecule)
# --> 475 molecule.assign_partial_charges(method)
#     477 return molecule.partial_charges
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/toolkit/topology/molecule.py:2672, in FrozenMolecule.assign_partial_charges(self, partial_charge_method, strict_n_conformers, use_conformers, toolkit_registry, normalize_partial_charges)
#    2658         warnings.warn(
#    2659             f"Warning! Partial charge method '{partial_charge_method}' is not designed "
#    2660             "for use on large (i.e. > 150 atoms) molecules and may crash or take hours to "
#    (...)
#    2664             stacklevel=2,
#    2665         )
#    2667 if isinstance(toolkit_registry, ToolkitRegistry):
#    2668     # We may need to try several toolkitwrappers to find one
#    2669     # that supports the desired partial charge method, so we
#    2670     # tell the ToolkitRegistry to continue trying ToolkitWrappers
#    2671     # if one raises an error (raise_exception_types=[])
# -> 2672     toolkit_registry.call(
#    2673         "assign_partial_charges",
#    2674         molecule=self,
#    2675         partial_charge_method=partial_charge_method,
#    2676         use_conformers=use_conformers,
#    2677         strict_n_conformers=strict_n_conformers,
#    2678         normalize_partial_charges=normalize_partial_charges,
#    2679         raise_exception_types=[],
#    2680         _cls=self.__class__,
#    2681     )
#    2682 elif isinstance(toolkit_registry, ToolkitWrapper):
#    2683     toolkit_wrapper: ToolkitWrapper = toolkit_registry
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/toolkit/utils/toolkit_registry.py:262, in ToolkitRegistry.call(self, method_name, raise_exception_types, *args, **kwargs)
#     260 method = getattr(toolkit, method_name)
#     261 try:
# --> 262     return method(*args, **kwargs)
#     263 except Exception as e:
#     264     for exception_type in raise_exception_types:
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/toolkit/utils/ambertools_wrapper.py:212, in AmberToolsToolkitWrapper.assign_partial_charges(self, molecule, partial_charge_method, use_conformers, strict_n_conformers, normalize_partial_charges, _cls)
#     209 # Compute desired charges
#     210 # TODO: Add error handling if antechamber chokes
#     211 short_charge_method = charge_method["antechamber_keyword"]
# --> 212 subprocess.check_output(
#     213     [
#     214         "antechamber",
#     215         "-i",
#     216         "molecule.sdf",
#     217         "-fi",
#     218         "sdf",
#     219         "-o",
#     220         "charged.mol2",
#     221         "-fo",
#     222         "mol2",
#     223         "-pf",
#     224         "yes",
#     225         "-dr",
#     226         "n",
#     227         "-c",
#     228         str(short_charge_method),
#     229         "-nc",
#     230         str(net_charge),
#     231     ],
#     232     cwd=tmpdir,
#     233 )
#     234 # Write out just charges
#     235 subprocess.check_output(
#     236     [
#     237         "antechamber",
#    (...)
#     255     cwd=tmpdir,
#     256 )
#
# File ~/micromamba/envs/melanin/lib/python3.12/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File ~/micromamba/envs/melanin/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/micromamba/envs/melanin/lib/python3.12/subprocess.py:1196, in Popen.communicate(self, input, timeout)
#    1194     self._stdin_write(input)
#    1195 elif self.stdout:
# -> 1196     stdout = self.stdout.read()
#    1197     self.stdout.close()
#    1198 elif self.stderr:
#
# KeyboardInterrupt:

# %%
# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

#get_summary_data(interchange, _engines='OpenMM')

# %%
bespokeff = ('Bespoke.offxml')

interchange_bespoke = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml", bespokeff))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 bespokeff = ('Bespoke.offxml')
# ----> 3 interchange_bespoke = Interchange.from_smirnoff(topology=openff_top,
#       4                                         force_field=ForceField("openff-2.2.0.offxml", bespokeff))
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/components/interchange.py:150, in Interchange.from_smirnoff(cls, force_field, topology, box, positions, charge_from_molecules, partial_bond_orders_from_molecules, allow_nonintegral_charges)
#      95 """
#      96 Create a new object by parameterizing a topology with a SMIRNOFF force field.
#      97
#    (...)
#     146
#     147 """
#     148 from openff.interchange.smirnoff._create import _create_interchange
# --> 150 return _create_interchange(
#     151     force_field=force_field,
#     152     topology=topology,
#     153     box=box,
#     154     positions=positions,
#     155     charge_from_molecules=charge_from_molecules,
#     156     partial_bond_orders_from_molecules=partial_bond_orders_from_molecules,
#     157     allow_nonintegral_charges=allow_nonintegral_charges,
#     158 )
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_create.py:137, in _create_interchange(force_field, topology, box, positions, charge_from_molecules, partial_bond_orders_from_molecules, allow_nonintegral_charges)
#     134 _impropers(interchange, force_field, interchange.topology)
#     136 _vdw(interchange, force_field, interchange.topology)
# --> 137 _electrostatics(
#     138     interchange,
#     139     force_field,
#     140     interchange.topology,
#     141     charge_from_molecules,
#     142     allow_nonintegral_charges,
#     143 )
#     144 _plugins(interchange, force_field, interchange.topology)
#     146 _virtual_sites(interchange, force_field, interchange.topology)
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_create.py:292, in _electrostatics(interchange, force_field, topology, charge_from_molecules, allow_nonintegral_charges)
#     287     else:
#     288         return
#     290 interchange.collections.update(
#     291     {
# --> 292         "Electrostatics": SMIRNOFFElectrostaticsCollection.create(
#     293             parameter_handler=[
#     294                 handler
#     295                 for handler in [
#     296                     force_field._parameter_handlers.get(name, None)
#     297                     for name in [
#     298                         "Electrostatics",
#     299                         "ChargeIncrementModel",
#     300                         "ToolkitAM1BCC",
#     301                         "LibraryCharges",
#     302                     ]
#     303                 ]
#     304                 if handler is not None
#     305             ],
#     306             topology=topology,
#     307             charge_from_molecules=charge_from_molecules,
#     308             allow_nonintegral_charges=allow_nonintegral_charges,
#     309         ),
#     310     },
#     311 )
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_nonbonded.py:455, in SMIRNOFFElectrostaticsCollection.create(cls, parameter_handler, topology, charge_from_molecules, allow_nonintegral_charges)
#     441 toolkit_handler_with_metadata = [p for p in parameter_handlers if type(p) is ElectrostaticsHandler][0]
#     443 handler = cls(
#     444     type=toolkit_handler_with_metadata.TAGNAME,
#     445     scale_12=toolkit_handler_with_metadata.scale12,
#    (...)
#     452     exception_potential=toolkit_handler_with_metadata.exception_potential,
#     453 )
# --> 455 handler.store_matches(
#     456     parameter_handlers,
#     457     topology,
#     458     charge_from_molecules=charge_from_molecules,
#     459     allow_nonintegral_charges=allow_nonintegral_charges,
#     460 )
#     461 handler._charges = dict()
#     463 return handler
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_nonbonded.py:856, in SMIRNOFFElectrostaticsCollection.store_matches(self, parameter_handler, topology, charge_from_molecules, allow_nonintegral_charges)
#     851 # TODO: Here is where the toolkit calls self.check_charges_assigned(). Do we skip this
#     852 #       entirely given that we are not accepting `charge_from_molecules`?
#     854 if not flag:
#     855     # TODO: Rename this method to something like `_find_matches`
# --> 856     matches, potentials = self._find_reference_matches(
#     857         parameter_handlers,
#     858         unique_molecule,
#     859     )
#     861 self.potentials.update(potentials)
#     863 for unique_molecule_atom in unique_molecule.atoms:
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_nonbonded.py:720, in SMIRNOFFElectrostaticsCollection._find_reference_matches(cls, parameter_handlers, unique_molecule)
#     710     slot_matches, slot_potentials = cls._find_slot_matches(
#     711         parameter_handler,
#     712         unique_molecule,
#     713     )
#     715 if handler_type in ["ToolkitAM1BCC", "ChargeIncrementModel"]:
#     716     (
#     717         partial_charge_method,
#     718         am1_matches,
#     719         am1_potentials,
# --> 720     ) = cls._find_charge_model_matches(
#     721         parameter_handler,
#     722         unique_molecule,
#     723     )
#     725 if slot_matches is None and am1_matches is None:
#     726     raise NotImplementedError()
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_nonbonded.py:658, in SMIRNOFFElectrostaticsCollection._find_charge_model_matches(cls, parameter_handler, unique_molecule)
#     652 else:
#     653     raise InvalidParameterHandlerError(
#     654         f"Encountered unknown handler of type {type(parameter_handler)} where only "
#     655         "ToolkitAM1BCCHandler or ChargeIncrementModelHandler are expected.",
#     656     )
# --> 658 partial_charges = cls._compute_partial_charges(
#     659     unique_molecule,
#     660     unique_molecule.to_smiles(
#     661         isomeric=True,
#     662         explicit_hydrogens=True,
#     663         mapped=True,
#     664     ),
#     665     method=partial_charge_method,
#     666 )
#     668 matches = {}
#     669 potentials = {}
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/interchange/smirnoff/_nonbonded.py:475, in SMIRNOFFElectrostaticsCollection._compute_partial_charges(cls, molecule, mapped_smiles, method)
#     473 """Call out to the toolkit's toolkit wrappers to generate partial charges."""
#     474 molecule = copy.deepcopy(molecule)
# --> 475 molecule.assign_partial_charges(method)
#     477 return molecule.partial_charges
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/toolkit/topology/molecule.py:2672, in FrozenMolecule.assign_partial_charges(self, partial_charge_method, strict_n_conformers, use_conformers, toolkit_registry, normalize_partial_charges)
#    2658         warnings.warn(
#    2659             f"Warning! Partial charge method '{partial_charge_method}' is not designed "
#    2660             "for use on large (i.e. > 150 atoms) molecules and may crash or take hours to "
#    (...)
#    2664             stacklevel=2,
#    2665         )
#    2667 if isinstance(toolkit_registry, ToolkitRegistry):
#    2668     # We may need to try several toolkitwrappers to find one
#    2669     # that supports the desired partial charge method, so we
#    2670     # tell the ToolkitRegistry to continue trying ToolkitWrappers
#    2671     # if one raises an error (raise_exception_types=[])
# -> 2672     toolkit_registry.call(
#    2673         "assign_partial_charges",
#    2674         molecule=self,
#    2675         partial_charge_method=partial_charge_method,
#    2676         use_conformers=use_conformers,
#    2677         strict_n_conformers=strict_n_conformers,
#    2678         normalize_partial_charges=normalize_partial_charges,
#    2679         raise_exception_types=[],
#    2680         _cls=self.__class__,
#    2681     )
#    2682 elif isinstance(toolkit_registry, ToolkitWrapper):
#    2683     toolkit_wrapper: ToolkitWrapper = toolkit_registry
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/toolkit/utils/toolkit_registry.py:262, in ToolkitRegistry.call(self, method_name, raise_exception_types, *args, **kwargs)
#     260 method = getattr(toolkit, method_name)
#     261 try:
# --> 262     return method(*args, **kwargs)
#     263 except Exception as e:
#     264     for exception_type in raise_exception_types:
#
# File ~/micromamba/envs/melanin/lib/python3.12/site-packages/openff/toolkit/utils/ambertools_wrapper.py:212, in AmberToolsToolkitWrapper.assign_partial_charges(self, molecule, partial_charge_method, use_conformers, strict_n_conformers, normalize_partial_charges, _cls)
#     209 # Compute desired charges
#     210 # TODO: Add error handling if antechamber chokes
#     211 short_charge_method = charge_method["antechamber_keyword"]
# --> 212 subprocess.check_output(
#     213     [
#     214         "antechamber",
#     215         "-i",
#     216         "molecule.sdf",
#     217         "-fi",
#     218         "sdf",
#     219         "-o",
#     220         "charged.mol2",
#     221         "-fo",
#     222         "mol2",
#     223         "-pf",
#     224         "yes",
#     225         "-dr",
#     226         "n",
#     227         "-c",
#     228         str(short_charge_method),
#     229         "-nc",
#     230         str(net_charge),
#     231     ],
#     232     cwd=tmpdir,
#     233 )
#     234 # Write out just charges
#     235 subprocess.check_output(
#     236     [
#     237         "antechamber",
#    (...)
#     255     cwd=tmpdir,
#     256 )
#
# File ~/micromamba/envs/melanin/lib/python3.12/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File ~/micromamba/envs/melanin/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/micromamba/envs/melanin/lib/python3.12/subprocess.py:1196, in Popen.communicate(self, input, timeout)
#    1194     self._stdin_write(input)
#    1195 elif self.stdout:
# -> 1196     stdout = self.stdout.read()
#    1197     self.stdout.close()
#    1198 elif self.stderr:
#
# KeyboardInterrupt:
# /Users/darv/micromamba/envs/melanin/bin/wrapped_progs/antechamber: Fatal Error!
# Cannot open file (sqm.out) with mode (r).
# No such file or directory
# /Users/darv/micromamba/envs/melanin/bin/wrapped_progs/antechamber: Fatal Error!
# Cannot open file (sqm.out) with mode (r).
# No such file or directory

# %%
os.chdir('torsion_1_xyz/')

# %%
dimer_openff = Molecule.from_file('tor_1_0.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond     Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  9.657451  68.94504  0.015348      -64.278217  46.847644     61.187266

# %%
dimer_openff = Molecule.from_file('tor_1_0.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond     Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  9.657451  68.94504  0.015348      -64.278217  46.847644     61.187266

# %%
dimer_openff = Molecule.from_file('tor_1_10.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond     Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  9.374066  68.58531  6.092081      -64.221697  45.853883     65.683642

# %%
dimer_openff = Molecule.from_file('tor_1_20.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  9.156748  68.931743  10.694574      -63.995925  44.314461
#
#         Total Energy
# OpenMM     69.101601

# %%
dimer_openff = Molecule.from_file('tor_1_20.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  9.156748  68.931743  10.694574      -63.995925  44.314461
#
#         Total Energy
# OpenMM     69.101601

# %%
dimer_openff = Molecule.from_file('tor_1_30.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  8.944415  69.491847  14.57444      -63.657843  42.866483     72.219342

# %%
dimer_openff = Molecule.from_file('tor_1_30.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  8.944415  69.491847  14.57444      -63.657843  42.866483     72.219342

# %%
dimer_openff = Molecule.from_file('tor_1_40.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond     Angle    Torsion  Electrostatics        vdW  Total Energy
# OpenMM  8.768475  69.90974  19.114656      -63.257641  41.622009     76.157238

# %%
dimer_openff = Molecule.from_file('tor_1_40.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond     Angle    Torsion  Electrostatics        vdW  Total Energy
# OpenMM  8.768475  69.90974  19.114656      -63.257641  41.622009     76.157238

# %%
dimer_openff = Molecule.from_file('tor_1_50.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.619549  70.095569  24.507576      -62.813599  40.684578
#
#         Total Energy
# OpenMM     81.093673

# %%
dimer_openff = Molecule.from_file('tor_1_50.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.619549  70.095569  24.507576      -62.813599  40.684578
#
#         Total Energy
# OpenMM     81.093673

# %%
dimer_openff = Molecule.from_file('tor_1_60.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.475297  70.119861  30.511793      -62.416371  40.004125
#
#         Total Energy
# OpenMM     86.694705

# %%
dimer_openff = Molecule.from_file('tor_1_60.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.475297  70.119861  30.511793      -62.416371  40.004125
#
#         Total Energy
# OpenMM     86.694705

# %%
dimer_openff = Molecule.from_file('tor_1_70.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.361548  70.048493  36.292579      -62.170989  39.534326
#
#         Total Energy
# OpenMM     92.065958

# %%
dimer_openff = Molecule.from_file('tor_1_70.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.361548  70.048493  36.292579      -62.170989  39.534326
#
#         Total Energy
# OpenMM     92.065958

# %%
dimer_openff = Molecule.from_file('tor_1_80.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.288105  70.076387  40.558961      -62.160763  39.216641
#
#         Total Energy
# OpenMM      95.97933

# %%
dimer_openff = Molecule.from_file('tor_1_80.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.288105  70.076387  40.558961      -62.160763  39.216641
#
#         Total Energy
# OpenMM      95.97933

# %%
dimer_openff = Molecule.from_file('tor_1_90.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.294388  70.108486  42.169092      -62.462059  39.042517
#
#         Total Energy
# OpenMM     97.152424

# %%
dimer_openff = Molecule.from_file('tor_1_90.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.294388  70.108486  42.169092      -62.462059  39.042517
#
#         Total Energy
# OpenMM     97.152424

# %%
dimer_openff = Molecule.from_file('tor_1_100.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.356534  69.973466  40.674437      -63.122789  39.010686
#
#         Total Energy
# OpenMM     94.892334

# %%
dimer_openff = Molecule.from_file('tor_1_100.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.356534  69.973466  40.674437      -63.122789  39.010686
#
#         Total Energy
# OpenMM     94.892334

# %%
dimer_openff = Molecule.from_file('tor_1_110.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.451048  69.520881  37.184038      -64.201277  39.167397
#
#         Total Energy
# OpenMM     90.122086

# %%
dimer_openff = Molecule.from_file('tor_1_110.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.451048  69.520881  37.184038      -64.201277  39.167397
#
#         Total Energy
# OpenMM     90.122086

# %%
dimer_openff = Molecule.from_file('tor_1_120.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.613875  68.956125  33.035704      -65.726503  39.690745
#
#         Total Energy
# OpenMM     84.569945

# %%
dimer_openff = Molecule.from_file('tor_1_120.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  8.613875  68.956125  33.035704      -65.726503  39.690745
#
#         Total Energy
# OpenMM     84.569945

# %%
dimer_openff = Molecule.from_file('tor_1_130.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  8.840315  68.844199  27.40468      -67.370443  40.744694     78.463445

# %%
dimer_openff = Molecule.from_file('tor_1_130.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  8.840315  68.844199  27.40468      -67.370443  40.744694     78.463445

# %%
dimer_openff = Molecule.from_file('tor_1_140.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  9.158456  69.178992  20.033866      -68.782964  42.183016
#
#         Total Energy
# OpenMM     71.771366

# %%
dimer_openff = Molecule.from_file('tor_1_140.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  9.158456  69.178992  20.033866      -68.782964  42.183016
#
#         Total Energy
# OpenMM     71.771366

# %%
dimer_openff = Molecule.from_file('tor_1_150.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  9.461668  69.717786  12.357442      -69.877913  43.699468
#
#         Total Energy
# OpenMM      65.35845

# %%
dimer_openff = Molecule.from_file('tor_1_150.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  9.461668  69.717786  12.357442      -69.877913  43.699468
#
#         Total Energy
# OpenMM      65.35845

# %%
dimer_openff = Molecule.from_file('tor_1_160.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle  Torsion  Electrostatics        vdW  Total Energy
# OpenMM  9.762014  70.233697   5.8398      -70.692651  45.130194     60.273054

# %%
dimer_openff = Molecule.from_file('tor_1_160.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle  Torsion  Electrostatics        vdW  Total Energy
# OpenMM  9.762014  70.233697   5.8398      -70.692651  45.130194     60.273054

# %%
dimer_openff = Molecule.from_file('tor_1_170.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  9.955841  70.620115  1.527917      -71.220558  46.182273     57.065589

# %%
dimer_openff = Molecule.from_file('tor_1_170.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  9.955841  70.620115  1.527917      -71.220558  46.182273     57.065589

# %%
dimer_openff = Molecule.from_file('tor_1_180.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle  Torsion  Electrostatics        vdW  Total Energy
# OpenMM  10.035327  70.700947  0.01181      -71.395504  46.563804     55.916385

# %%
dimer_openff = Molecule.from_file('tor_1_180.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle  Torsion  Electrostatics        vdW  Total Energy
# OpenMM  10.035327  70.700947  0.01181      -71.395504  46.563804     55.916385

# %%
import numpy as np
lowest_conformation = 0
highest_conformation = 190
increment = 10
bottom = -180

listangles = np.arange(lowest_conformation, highest_conformation, increment)
totalangles = np.concatenate((np.arange(bottom, lowest_conformation, increment), listangles))

listenergies = (55.916385, 57.065589, 60.273054, 65.35845, 71.771366, 78.463445, 84.569945, 90.122086, 94.892334, 97.152424, 95.97933, 92.065958, 86.694705, 81.093673, 76.157238, 72.219342, 69.101601, 65.683642, 61.187266, 65.683642, 69.101601, 72.219342, 76.157238, 81.093673, 86.694705, 92.065958, 95.97933, 97.152424, 94.892334, 90.122086, 84.569945, 78.463445, 71.771366, 65.35845, 60.273054, 57.065589, 55.916385)
listenergies_kcal = [energy / 4.184 for energy in listenergies]


import matplotlib.pyplot as plt
plt.plot(totalangles, listenergies_kcal)
plt.ylim(bottom=0)
plt.grid(True, alpha=0.5)
plt.xticks(np.arange(bottom, highest_conformation, 30))

plt.xlabel('Angle (degrees)')
plt.ylabel('Energy (kcal/mol)')
plt.title('Energy vs. Angle (Bespoke)')
plt.show()

# %%
lowest_conformation = 0
highest_conformation = 190
increment = 10
bottom = -180

listangles2 = np.arange(lowest_conformation, highest_conformation, increment)
totalangles2 = np.concatenate((np.arange(bottom, lowest_conformation, increment), listangles))

listenergies2 = (55.916385, 57.065589, 60.273054, 65.35845, 71.771366, 78.463445, 84.569945, 90.122086, 94.892334, 97.152424, 95.97933, 92.065958, 86.694705, 81.093673, 76.157238, 72.219342, 69.101601, 65.683642, 61.187266, 65.683642, 69.101601, 72.219342, 76.157238, 81.093673, 86.694705, 92.065958, 95.97933, 97.152424, 94.892334, 90.122086, 84.569945, 78.463445, 71.771366, 65.35845, 60.273054, 57.065589, 55.916385)
listenergies_kcal2 = [energy / 4.184 for energy in listenergies2]

plt.plot(totalangles2, listenergies_kcal2)
plt.ylim(bottom=0)
plt.grid(True, alpha=0.5)
plt.xticks(np.arange(bottom, highest_conformation, 30))

plt.plot(totalangles2, listenergies_kcal2, color='red')
plt.xlabel('Angle (degrees)')
plt.ylabel('Energy (kcal/mol)')
plt.title('Energy vs. Angle (Sage)')
plt.show()

# %%
import matplotlib.pyplot as plt


# Normalize the energies to make the lowest value 0
listenergies_kcal_normalized = [energy - min(listenergies_kcal) for energy in listenergies_kcal]
listenergies_kcal2_normalized = [energy - min(listenergies_kcal2) for energy in listenergies_kcal2]

plt.plot(totalangles, listenergies_kcal_normalized, label='Bespoke', color='blue')
plt.plot(totalangles2, listenergies_kcal2_normalized, label='Sage', color='red', linestyle='--')
plt.scatter(totalangles, listenergies_kcal_normalized, color='blue', s=10)
plt.scatter(totalangles2, listenergies_kcal2_normalized, color='red', s=10)
plt.ylim(bottom=0)
plt.xticks(np.arange(bottom, highest_conformation, 30))

plt.xlabel('Angle (degrees)')
plt.ylabel('Energy (kcal/mol)')
plt.title('Energy vs. Angle for $\\theta$₁ (Bespoke and Sage)')
plt.legend()
plt.show()
