# %%
import rdkit
from rdkit import Chem
import os
import random
import pandas as pd
import time
import numpy as np
#import mdtraj as md
import nglview
import openmm
from openbabel import openbabel

from openff.toolkit.topology import Molecule, Topology
from openff.toolkit.typing.engines.smirnoff import ForceField
from openff.toolkit.utils import get_data_file_path
from openff.toolkit.utils.toolkits import RDKitToolkitWrapper, OpenEyeToolkitWrapper, AmberToolsToolkitWrapper
from openff.units import unit
from pandas import read_csv

from openff.interchange import Interchange
from openff.interchange.components._packmol import UNIT_CUBE, pack_box, RHOMBIC_DODECAHEDRON
from openff.interchange.components._packmol import _max_dist_between_points, _compute_brick_from_box_vectors, _center_topology_at
from openmm.openmm import System
from openmm import MonteCarloBarostat

import subprocess
from openmm.app.simulation import Simulation
#from  rdkit  import  Chem
from  rdkit.Chem  import  rdDistGeom
from  rdkit.Chem.Draw  import  IPythonConsole
import warnings
warnings.filterwarnings('ignore')

# %%
smi = 'COC1=CC2=C(C=C1OC)N([H])C(C3=C(OCCOCCOCCOC)C=C(S3)C4=CC=C(C5=CC(OCCOCCOCCOC)=C(C(N6[H])=CC7=C6C=C(C(OC)=C7)OC)S5)C8=NSN=C48)=C2'

dimer_openff = Molecule.from_file('darvin_mol_1_set_ang.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")

# %%
# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 from openff.interchange.drivers import get_summary_data
#       3 from openff.interchange.drivers import get_openmm_energies
# ----> 5 get_summary_data(interchange, _engines='OpenMM')
#
# NameError: name 'interchange' is not defined

# %%
bespokeff = ('Bespoke.offxml')

interchange_bespoke = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml", bespokeff))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 bespokeff = ('Bespoke.offxml')
# ----> 3 interchange_bespoke = Interchange.from_smirnoff(topology=openff_top,
#       4                                         force_field=ForceField("openff-2.2.0.offxml", bespokeff))
#
# NameError: name 'openff_top' is not defined

# %%
os.chdir('torsion_2_xyz/')

# %%
dimer_openff = Molecule.from_file('tor_2_0.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
# python(14369) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# python(14411) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#             Bond      Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  22.00225  54.782285  0.002543       -58.45682  35.737785     54.068043

# %%
dimer_openff = Molecule.from_file('tor_2_0.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  22.00225  54.782285  0.002543       -58.45682  35.737785     54.068043

# %%
smi = 'COC1=CC2=C(C=C1OC)N([H])C(C3=C(OCCOCCOCCOC)C=C(S3)C4=CC=C(C5=CC(OCCOCCOCCOC)=C(C(N6[H])=CC7=C6C=C(C(OC)=C7)OC)S5)C8=NSN=C48)=C2'

dimer_openff = Molecule.from_file('tor_2_10.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle   Torsion  Electrostatics        vdW  \
# OpenMM  21.925063  54.657831  1.362154      -58.298136  33.717462
#
#         Total Energy
# OpenMM     53.364373

# %%
dimer_openff = Molecule.from_file('tor_2_10.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle   Torsion  Electrostatics        vdW  \
# OpenMM  21.925063  54.657831  1.362154      -58.298136  33.717462
#
#         Total Energy
# OpenMM     53.364373

# %%
dimer_openff = Molecule.from_file('tor_2_20.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle   Torsion  Electrostatics        vdW  \
# OpenMM  21.700267  54.282078  4.864766      -57.898553  29.342697
#
#         Total Energy
# OpenMM     52.291255

# %%
dimer_openff = Molecule.from_file('tor_2_20.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle   Torsion  Electrostatics        vdW  \
# OpenMM  21.700267  54.282078  4.864766      -57.898553  29.342697
#
#         Total Energy
# OpenMM     52.291255

# %%
dimer_openff = Molecule.from_file('tor_2_30.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle   Torsion  Electrostatics        vdW  \
# OpenMM  21.428547  53.929972  9.756926      -57.376974  24.891482
#
#         Total Energy
# OpenMM     52.629954

# %%
dimer_openff = Molecule.from_file('tor_2_30.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle   Torsion  Electrostatics        vdW  \
# OpenMM  21.428547  53.929972  9.756926      -57.376974  24.891482
#
#         Total Energy
# OpenMM     52.629954

# %%
dimer_openff = Molecule.from_file('tor_2_40.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.236762  53.447693  15.674187      -56.808213  21.268054
#
#         Total Energy
# OpenMM     54.818484

# %%
dimer_openff = Molecule.from_file('tor_2_40.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.236762  53.447693  15.674187      -56.808213  21.268054
#
#         Total Energy
# OpenMM     54.818484

# %%
dimer_openff = Molecule.from_file('tor_2_50.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.134647  53.023059  22.289815      -56.233388  18.585398
#
#         Total Energy
# OpenMM     58.799531

# %%
dimer_openff = Molecule.from_file('tor_2_50.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.134647  53.023059  22.289815      -56.233388  18.585398
#
#         Total Energy
# OpenMM     58.799531

# %%
dimer_openff = Molecule.from_file('tor_2_60.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics       vdW  \
# OpenMM  21.131433  52.557388  29.089423      -55.675043  16.73491
#
#         Total Energy
# OpenMM     63.838111

# %%
dimer_openff = Molecule.from_file('tor_2_60.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics       vdW  \
# OpenMM  21.131433  52.557388  29.089423      -55.675043  16.73491
#
#         Total Energy
# OpenMM     63.838111

# %%
dimer_openff = Molecule.from_file('tor_2_70.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.17759  52.234694  35.273732      -55.161996  15.531211
#
#         Total Energy
# OpenMM      69.05523

# %%
dimer_openff = Molecule.from_file('tor_2_70.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.17759  52.234694  35.273732      -55.161996  15.531211
#
#         Total Energy
# OpenMM      69.05523

# %%
dimer_openff = Molecule.from_file('tor_2_80.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.222385  51.964044  39.759237      -54.721688  14.954726
#
#         Total Energy
# OpenMM     73.178704

# %%
dimer_openff = Molecule.from_file('tor_2_80.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.222385  51.964044  39.759237      -54.721688  14.954726
#
#         Total Energy
# OpenMM     73.178704

# %%
dimer_openff = Molecule.from_file('tor_2_90.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.166336  51.759554  41.438478      -54.369241  14.771555
#
#         Total Energy
# OpenMM     74.766682

# %%
dimer_openff = Molecule.from_file('tor_2_90.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.166336  51.759554  41.438478      -54.369241  14.771555
#
#         Total Energy
# OpenMM     74.766682

# %%
dimer_openff = Molecule.from_file('tor_2_100.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.078527  51.601509  39.765131      -54.068885  14.963354
#
#         Total Energy
# OpenMM     73.339637

# %%
dimer_openff = Molecule.from_file('tor_2_100.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.078527  51.601509  39.765131      -54.068885  14.963354
#
#         Total Energy
# OpenMM     73.339637

# %%
dimer_openff = Molecule.from_file('tor_2_110.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  20.925687  51.382713  35.306436      -53.751905  15.605732
#
#         Total Energy
# OpenMM     69.468664

# %%
dimer_openff = Molecule.from_file('tor_2_110.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  20.925687  51.382713  35.306436      -53.751905  15.605732
#
#         Total Energy
# OpenMM     69.468664

# %%
dimer_openff = Molecule.from_file('tor_2_120.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  20.920827  51.280214  29.241339      -53.363955  16.883277
#
#         Total Energy
# OpenMM     64.961702

# %%
dimer_openff = Molecule.from_file('tor_2_120.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  20.920827  51.280214  29.241339      -53.363955  16.883277
#
#         Total Energy
# OpenMM     64.961702

# %%
dimer_openff = Molecule.from_file('tor_2_130.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  20.93825  51.448243  22.577426       -52.90394  18.924807
#
#         Total Energy
# OpenMM     60.984786

# %%
dimer_openff = Molecule.from_file('tor_2_130.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#             Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  20.93825  51.448243  22.577426       -52.90394  18.924807
#
#         Total Energy
# OpenMM     60.984786

# %%
dimer_openff = Molecule.from_file('tor_2_140.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.022144  51.810187  16.037747      -52.387743  21.886325
#
#         Total Energy
# OpenMM     58.368659

# %%
dimer_openff = Molecule.from_file('tor_2_140.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.022144  51.810187  16.037747      -52.387743  21.886325
#
#         Total Energy
# OpenMM     58.368659

# %%
dimer_openff = Molecule.from_file('tor_2_150.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond     Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.106515  52.32749  10.077292      -51.835949  25.773745
#
#         Total Energy
# OpenMM     57.449094

# %%
dimer_openff = Molecule.from_file('tor_2_150.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond     Angle    Torsion  Electrostatics        vdW  \
# OpenMM  21.106515  52.32749  10.077292      -51.835949  25.773745
#
#         Total Energy
# OpenMM     57.449094

# %%
dimer_openff = Molecule.from_file('tor_2_160.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle   Torsion  Electrostatics        vdW  \
# OpenMM  21.218075  53.089379  5.060131      -51.304551  30.207076
#
#         Total Energy
# OpenMM      58.27011

# %%
dimer_openff = Molecule.from_file('tor_2_160.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle   Torsion  Electrostatics        vdW  \
# OpenMM  21.218075  53.089379  5.060131      -51.304551  30.207076
#
#         Total Energy
# OpenMM      58.27011

# %%
dimer_openff = Molecule.from_file('tor_2_170.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond      Angle   Torsion  Electrostatics        vdW  \
# OpenMM  21.305125  53.714976  1.396312      -50.870543  34.232233
#
#         Total Energy
# OpenMM     59.778103

# %%
dimer_openff = Molecule.from_file('tor_2_170.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond      Angle   Torsion  Electrostatics        vdW  \
# OpenMM  21.305125  53.714976  1.396312      -50.870543  34.232233
#
#         Total Energy
# OpenMM     59.778103

# %%
dimer_openff = Molecule.from_file('tor_2_180.mol')
bespokeff = ('Bespoke.offxml')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml",bespokeff))

interchange.to_pdb("interchange.pdb")

# Finding the total energy
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange, _engines='OpenMM')
# Out:
#              Bond     Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  21.343919  54.04471  0.002693      -50.694321  35.929181     60.626182

# %%
dimer_openff = Molecule.from_file('tor_2_180.mol')


#Convert to OpenFF topology
openff_top = dimer_openff.to_topology()

interchange_ff = Interchange.from_smirnoff(topology=openff_top, 
                                        force_field=ForceField("openff-2.2.0.offxml"))

interchange.to_pdb("interchange.pdb")
from openff.interchange.drivers import get_summary_data
from openff.interchange.drivers import get_openmm_energies

get_summary_data(interchange_ff, _engines='OpenMM')
# Out:
#              Bond     Angle   Torsion  Electrostatics        vdW  Total Energy
# OpenMM  21.343919  54.04471  0.002693      -50.694321  35.929181     60.626182

# %%
import numpy as np
lowest_conformation = 0
highest_conformation = 190
increment = 10
bottom = -180

listangles = np.arange(lowest_conformation, highest_conformation, increment)
totalangles = np.concatenate((np.arange(bottom, lowest_conformation, increment), listangles))

listenergies = (60.626182, 59.778103, 58.27011, 60.626182, 59.778103, 58.27011, 57.449094, 58.368659, 60.984786, 64.961702, 69.468664, 73.339637, 74.766682, 73.178704, 69.05523, 63.838111, 58.799531, 53.364373, 54.068043, 53.364373, 58.799531, 63.838111, 69.05523, 73.178704, 74.766682, 73.339637, 69.468664, 64.961702, 60.984786, 58.368659, 57.449094, 58.27011, 59.778103, 60.626182, 58.27011, 59.778103, 60.626182)
listenergies_kcal = [energy / 4.184 for energy in listenergies]


import matplotlib.pyplot as plt
plt.plot(totalangles, listenergies_kcal)
plt.ylim(bottom=0)
plt.grid(False)
plt.xticks(np.arange(bottom, highest_conformation, 30))

plt.xlabel('Angle (degrees)')
plt.ylabel('Energy (kcal/mol)')
plt.title('Energy vs. Angle (Bespoke)')
plt.show()

# %%
lowest_conformation = 0
highest_conformation = 190
increment = 10
bottom = -180

listangles2 = np.arange(lowest_conformation, highest_conformation, increment)
totalangles2 = np.concatenate((np.arange(bottom, lowest_conformation, increment), listangles))

listenergies2 = (60.626182, 59.778103, 58.27011, 60.626182, 59.778103, 58.27011, 57.449094, 58.368659, 60.984786, 64.961702, 69.468664, 73.339637, 74.766682, 73.178704, 69.05523, 63.838111, 58.799531, 53.364373, 54.068043, 53.364373, 58.799531, 63.838111, 69.05523, 73.178704, 74.766682, 73.339637, 69.468664, 64.961702, 60.984786, 58.368659, 57.449094, 58.27011, 59.778103, 60.626182, 58.27011, 59.778103, 60.626182)
listenergies_kcal2 = [energy / 4.184 for energy in listenergies2]

plt.plot(totalangles2, listenergies_kcal2)
plt.ylim(bottom=0)
plt.grid(False)
plt.xticks(np.arange(bottom, highest_conformation, 30))

plt.plot(totalangles2, listenergies_kcal2, color='red')
plt.xlabel('Angle (degrees)')
plt.ylabel('Energy (kcal/mol)')
plt.title('Energy vs. Angle (Sage)')
plt.show()

# %%
import matplotlib.pyplot as plt


min_energy = min(listenergies_kcal + listenergies_kcal2)
listenergies_kcal_normalized = [energy - min_energy for energy in listenergies_kcal]
listenergies_kcal2_normalized = [energy - min_energy for energy in listenergies_kcal2]

plt.plot(totalangles, listenergies_kcal_normalized, label='Bespoke', color='blue')
plt.plot(totalangles2, listenergies_kcal2_normalized, label='Sage', color='red', linestyle='--')

plt.ylim(bottom=0)
plt.xticks(np.arange(bottom, highest_conformation, 30))

plt.xlabel('Angle (degrees)')
plt.ylabel('Energy (kcal/mol)')
plt.title('Energy vs. Angle for $\\theta$₂ (Bespoke and Sage)')
plt.legend()
plt.show()
